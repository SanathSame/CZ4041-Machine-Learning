# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn import preprocessing 
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
import seaborn as sns
from tqdm import tqdm
from IPython.display import display

# pandas display options
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 300)
pd.set_option('float_format', '{:,.2f}'.format)

# %%
# datasets paths
# path = "../data"
path = "/content/drive/MyDrive/CZ4041/Dataset/" # path to Google Drive, for colab
macro = os.path.join(path, "macro.csv")
train = os.path.join(path, "train.csv")
test = os.path.join(path,  "test.csv")

# place all datasets paths in a datasets dict
datasets = {}
datasets['macro'] = macro
datasets['train'] = train
datasets['test'] = test


# load dataframes into dfs dict
dfs = {}
for dataset_name, path in datasets.items():
    df = pd.read_csv(path)
    dfs[dataset_name] = df

# assign to own df variables when you want to use them individually
df_macro = dfs['macro']
df_train = dfs['train']
df_test = dfs['test']

# %%
corr_vals = df_train.corr()
target_corr = abs(corr_vals["price_doc"])

relevant_features = target_corr[target_corr<=0.07]
print("Number of relevant features with corr <= 0.07: {}".format(len(relevant_features)))
print(relevant_features)
# Out:
# Number of relevant features with corr <= 0.25: 68
# material                                0.06
# build_year                              0.00
# kitch_sq                                0.03
# school_quota                            0.01
# additional_education_raion              0.06
# culture_objects_top_25_raion            0.04
# full_all                                0.03
# male_f                                  0.03
# female_f                                0.02
# 16_29_all                               0.02
# 16_29_male                              0.02
# 16_29_female                            0.02
# raion_build_count_with_material_info    0.06
# build_count_block                       0.03
# build_count_wood                        0.04
# build_count_frame                       0.03
# build_count_panel                       0.02
# build_count_foam                        0.01
# build_count_slag                        0.02
# build_count_mix                         0.03
# raion_build_count_with_builddate_info   0.06
# build_count_1921-1945                   0.02
# build_count_1946-1970                   0.06
# build_count_1971-1995                   0.01
# build_count_after_1995                  0.03
# ID_metro                                0.05
# green_zone_km                           0.06
# industrial_km                           0.05
# water_treatment_km                      0.05
# cemetery_km                             0.02
# incineration_km                         0.06
# ID_railroad_station_walk                0.02
# ID_railroad_station_avto                0.05
# water_km                                0.03
# mkad_km                                 0.02
# ID_big_road1                            0.07
# ID_bus_terminal                         0.05
# big_market_km                           0.05
# green_part_500                          0.05
# prom_part_500                           0.01
# trc_count_500                           0.06
# trc_sqm_500                             0.00
# cafe_sum_500_min_price_avg              0.04
# cafe_sum_500_max_price_avg              0.04
# cafe_avg_price_500                      0.04
# cafe_count_500_na_price                 0.05
# cafe_count_500_price_high               0.05
# big_church_count_500                    0.03
# church_count_500                        0.01
# mosque_count_500                        0.02
# market_count_500                        0.04
# green_part_1000                         0.06
# prom_part_1000                          0.06
# trc_sqm_1000                            0.04
# cafe_count_1000_price_4000              0.04
# church_count_1000                       0.05
# market_count_1000                       0.07
# prom_part_1500                          0.07
# cafe_count_1500_price_4000              0.06
# big_church_count_1500                   0.07
# prom_part_2000                          0.05
# prom_part_3000                          0.02
# cafe_sum_3000_min_price_avg             0.01
# cafe_sum_3000_max_price_avg             0.00
# cafe_avg_price_3000                     0.00
# cafe_sum_5000_min_price_avg             0.03
# cafe_sum_5000_max_price_avg             0.03
# cafe_avg_price_5000                     0.03
# Name: price_doc, dtype: float64
